# %%
# # Convolutional Neural Network

# Importing the libraries
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
tf.__version__

# Part 1 - Data Preprocessing

# Preprocessing the Training set
train_datagen = ImageDataGenerator(rescale=1./255,
      shear_range=0.2,
      zoom_range=0.2,
      horizontal_flip=True)
training_set = train_datagen.flow_from_directory('dataset/training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 16,
                                                 class_mode = 'binary')

# Preprocessing the Test set
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('dataset/test_set',
                                            target_size = (64, 64),
                                            batch_size = 16,
                                            class_mode = 'binary')

# Initialising the CNN
cnn = tf.keras.models.Sequential()

# Step 1 - Convolution
cnn.add(tf.keras.layers.Conv2D(filters=32,padding="same",kernel_size=3, activation='relu', input_shape=[64, 64, 3]))

# Step 2 - Pooling
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# Adding a second convolutional layer
cnn.add(tf.keras.layers.Conv2D(filters=32,padding='same',kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# Step 3 - Flattening
cnn.add(tf.keras.layers.Flatten())

# Step 4 - Full Connection
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# Step 5 - Output Layer
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Part 3 - Training the CNN

# Compiling the CNN
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
cnn.summary()

# Training the CNN on the Training set and evaluating it on the Test set
cnn.fit(x=training_set,epochs=30,validation_data=test_set)

# Part 4 - Making a single prediction

import numpy as np
from keras.preprocessing import image
test_image = image.load_img('dataset/single_prediction/cat_or_dog_1.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
    prediction = 'dog'
else:
    prediction = 'cat'
print(prediction)
# Out:
# Found 800 images belonging to 2 classes.
# Found 200 images belonging to 2 classes.
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 64, 64, 32)        896
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               1048704
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 1,058,977
# Trainable params: 1,058,977
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 50/50 [==============================] - 7s 124ms/step - loss: 0.7053 - accuracy: 0.4850 - val_loss: 0.6902 - val_accuracy: 0.5500
# Epoch 2/30
# 50/50 [==============================] - 6s 117ms/step - loss: 0.6895 - accuracy: 0.5625 - val_loss: 0.6926 - val_accuracy: 0.5150
# Epoch 3/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6832 - accuracy: 0.5400 - val_loss: 0.6812 - val_accuracy: 0.5700
# Epoch 4/30
# 50/50 [==============================] - 6s 121ms/step - loss: 0.6579 - accuracy: 0.6062 - val_loss: 0.9094 - val_accuracy: 0.5000
# Epoch 5/30
# 50/50 [==============================] - 6s 119ms/step - loss: 0.6548 - accuracy: 0.6187 - val_loss: 0.7157 - val_accuracy: 0.5750
# Epoch 6/30
# 50/50 [==============================] - 6s 116ms/step - loss: 0.6344 - accuracy: 0.6488 - val_loss: 0.6520 - val_accuracy: 0.6400
# Epoch 7/30
# 50/50 [==============================] - 6s 121ms/step - loss: 0.6091 - accuracy: 0.6850 - val_loss: 0.6351 - val_accuracy: 0.6450
# Epoch 8/30
# 50/50 [==============================] - 6s 121ms/step - loss: 0.5814 - accuracy: 0.6900 - val_loss: 0.6168 - val_accuracy: 0.6800
# Epoch 9/30
# 50/50 [==============================] - 6s 119ms/step - loss: 0.5648 - accuracy: 0.7088 - val_loss: 0.6958 - val_accuracy: 0.6200
# Epoch 10/30
# 50/50 [==============================] - 6s 124ms/step - loss: 0.5558 - accuracy: 0.7225 - val_loss: 0.6296 - val_accuracy: 0.7000
# Epoch 11/30
# 50/50 [==============================] - 6s 121ms/step - loss: 0.5191 - accuracy: 0.7250 - val_loss: 0.7737 - val_accuracy: 0.6000
# Epoch 12/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.5290 - accuracy: 0.7412 - val_loss: 0.7108 - val_accuracy: 0.6950
# Epoch 13/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.5069 - accuracy: 0.7462 - val_loss: 0.6587 - val_accuracy: 0.7000
# Epoch 14/30
# 50/50 [==============================] - 6s 121ms/step - loss: 0.4688 - accuracy: 0.7850 - val_loss: 0.7973 - val_accuracy: 0.6300
# Epoch 15/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.4724 - accuracy: 0.7713 - val_loss: 0.6717 - val_accuracy: 0.7100
# Epoch 16/30
# 50/50 [==============================] - 6s 119ms/step - loss: 0.4478 - accuracy: 0.7912 - val_loss: 0.7238 - val_accuracy: 0.6850
# Epoch 17/30
# 50/50 [==============================] - 6s 119ms/step - loss: 0.4065 - accuracy: 0.8188 - val_loss: 0.6819 - val_accuracy: 0.6850
# Epoch 18/30
# 50/50 [==============================] - 6s 121ms/step - loss: 0.4187 - accuracy: 0.8100 - val_loss: 0.6846 - val_accuracy: 0.7150
# Epoch 19/30
# 50/50 [==============================] - 6s 121ms/step - loss: 0.3750 - accuracy: 0.8250 - val_loss: 0.8854 - val_accuracy: 0.6700
# Epoch 20/30
# 50/50 [==============================] - 6s 118ms/step - loss: 0.3729 - accuracy: 0.8338 - val_loss: 0.7333 - val_accuracy: 0.7100
# Epoch 21/30
# 50/50 [==============================] - 6s 119ms/step - loss: 0.3858 - accuracy: 0.8288 - val_loss: 0.8338 - val_accuracy: 0.6650
# Epoch 22/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.3287 - accuracy: 0.8562 - val_loss: 0.8853 - val_accuracy: 0.6750
# Epoch 23/30
# 50/50 [==============================] - 6s 120ms/step - loss: 0.3281 - accuracy: 0.8550 - val_loss: 0.8618 - val_accuracy: 0.6950
# Epoch 24/30
# 50/50 [==============================] - 6s 119ms/step - loss: 0.2925 - accuracy: 0.8863 - val_loss: 0.7779 - val_accuracy: 0.7200
# Epoch 25/30
# 50/50 [==============================] - 6s 121ms/step - loss: 0.2448 - accuracy: 0.9050 - val_loss: 0.9088 - val_accuracy: 0.7000
# Epoch 26/30
# 50/50 [==============================] - 6s 120ms/step - loss: 0.2210 - accuracy: 0.9162 - val_loss: 0.9842 - val_accuracy: 0.6700
# Epoch 27/30
# 50/50 [==============================] - 6s 119ms/step - loss: 0.2975 - accuracy: 0.8537 - val_loss: 0.7716 - val_accuracy: 0.7000
# Epoch 28/30
# 50/50 [==============================] - 6s 121ms/step - loss: 0.2960 - accuracy: 0.8788 - val_loss: 0.8337 - val_accuracy: 0.7300
# Epoch 29/30
# 50/50 [==============================] - 6s 120ms/step - loss: 0.2359 - accuracy: 0.9038 - val_loss: 0.9910 - val_accuracy: 0.6800
# Epoch 30/30
# 50/50 [==============================] - 6s 118ms/step - loss: 0.2033 - accuracy: 0.9250 - val_loss: 1.0622 - val_accuracy: 0.6850
# dog
