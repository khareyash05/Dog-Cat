# %%
# # Convolutional Neural Network

# Importing the libraries
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
tf.__version__

# Part 1 - Data Preprocessing

# Preprocessing the Training set
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
      shear_range=0.2,
      zoom_range=0.2,
      horizontal_flip=True)
training_set = train_datagen.flow_from_directory('dataset/training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 16,
                                                 class_mode = 'binary')

# Preprocessing the Test set
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('dataset/test_set',
                                            target_size = (64, 64),
                                            batch_size = 16,
                                            class_mode = 'binary')

# Initialising the CNN
cnn = tf.keras.models.Sequential()

# Step 1 - Convolution
cnn.add(tf.keras.layers.Conv2D(filters=32,padding="same",kernel_size=3, activation='relu', input_shape=[64, 64, 3]))

# Step 2 - Pooling
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# Adding a second convolutional layer
cnn.add(tf.keras.layers.Conv2D(filters=32,padding='same',kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))
cnn.add(tf.keras.layers.Dropout(0.2))

# Step 3 - Flattening
cnn.add(tf.keras.layers.Flatten())

# Step 4 - Full Connection
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# Step 5 - Output Layer
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Part 3 - Training the CNN

# Compiling the CNN
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
cnn.summary()

# Training the CNN on the Training set and evaluating it on the Test set
cnn.fit(x=training_set,epochs=30,validation_data=test_set)

# Part 4 - Making a single prediction

import numpy as np
from keras.preprocessing import image
test_image = image.load_img('dataset/single_prediction/cat_or_dog_1.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
    prediction = 'dog'
else:
    prediction = 'cat'
print(prediction)
# Out:
# Found 800 images belonging to 2 classes.
# Found 200 images belonging to 2 classes.
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_16 (Conv2D)           (None, 64, 64, 32)        896
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 32)        0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               1048704
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 1,058,977
# Trainable params: 1,058,977
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 50/50 [==============================] - 7s 126ms/step - loss: 0.7129 - accuracy: 0.5075 - val_loss: 0.6921 - val_accuracy: 0.5000
# Epoch 2/30
# 50/50 [==============================] - 6s 120ms/step - loss: 0.6932 - accuracy: 0.4988 - val_loss: 0.6892 - val_accuracy: 0.5000
# Epoch 3/30
# 50/50 [==============================] - 6s 120ms/step - loss: 0.6910 - accuracy: 0.5213 - val_loss: 0.6849 - val_accuracy: 0.5650
# Epoch 4/30
# 50/50 [==============================] - 6s 126ms/step - loss: 0.6908 - accuracy: 0.5600 - val_loss: 0.6744 - val_accuracy: 0.6150
# Epoch 5/30
# 50/50 [==============================] - 6s 121ms/step - loss: 0.6822 - accuracy: 0.5825 - val_loss: 0.6694 - val_accuracy: 0.5600
# Epoch 6/30
# 50/50 [==============================] - 6s 120ms/step - loss: 0.6736 - accuracy: 0.5688 - val_loss: 0.6737 - val_accuracy: 0.5600
# Epoch 7/30
# 50/50 [==============================] - 6s 125ms/step - loss: 0.6819 - accuracy: 0.5813 - val_loss: 0.6810 - val_accuracy: 0.5550
# Epoch 8/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6821 - accuracy: 0.5700 - val_loss: 0.6675 - val_accuracy: 0.5700
# Epoch 9/30
# 50/50 [==============================] - 6s 126ms/step - loss: 0.6807 - accuracy: 0.6025 - val_loss: 0.6776 - val_accuracy: 0.5700
# Epoch 10/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.6838 - accuracy: 0.5688 - val_loss: 0.6738 - val_accuracy: 0.5600
# Epoch 11/30
# 50/50 [==============================] - 6s 121ms/step - loss: 0.6763 - accuracy: 0.5725 - val_loss: 0.6739 - val_accuracy: 0.5550
# Epoch 12/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.6750 - accuracy: 0.6000 - val_loss: 0.6646 - val_accuracy: 0.5850
# Epoch 13/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.6749 - accuracy: 0.5813 - val_loss: 0.6608 - val_accuracy: 0.5850
# Epoch 14/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.6689 - accuracy: 0.5987 - val_loss: 0.6646 - val_accuracy: 0.5750
# Epoch 15/30
# 50/50 [==============================] - 6s 121ms/step - loss: 0.6720 - accuracy: 0.5875 - val_loss: 0.6800 - val_accuracy: 0.5600
# Epoch 16/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.6714 - accuracy: 0.5950 - val_loss: 0.6659 - val_accuracy: 0.6100
# Epoch 17/30
# 50/50 [==============================] - 6s 121ms/step - loss: 0.6643 - accuracy: 0.6062 - val_loss: 0.6678 - val_accuracy: 0.5950
# Epoch 18/30
# 50/50 [==============================] - 6s 118ms/step - loss: 0.6691 - accuracy: 0.5962 - val_loss: 0.6635 - val_accuracy: 0.6150
# Epoch 19/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.6625 - accuracy: 0.6125 - val_loss: 0.6631 - val_accuracy: 0.5700
# Epoch 20/30
# 50/50 [==============================] - 7s 132ms/step - loss: 0.6570 - accuracy: 0.6212 - val_loss: 0.6791 - val_accuracy: 0.6150
# Epoch 21/30
# 50/50 [==============================] - 7s 142ms/step - loss: 0.6544 - accuracy: 0.6075 - val_loss: 0.6477 - val_accuracy: 0.5950
# Epoch 22/30
# 50/50 [==============================] - 6s 124ms/step - loss: 0.6492 - accuracy: 0.6400 - val_loss: 0.6454 - val_accuracy: 0.6350
# Epoch 23/30
# 50/50 [==============================] - 6s 124ms/step - loss: 0.6501 - accuracy: 0.6313 - val_loss: 0.6468 - val_accuracy: 0.6350
# Epoch 24/30
# 50/50 [==============================] - 6s 125ms/step - loss: 0.6437 - accuracy: 0.6075 - val_loss: 0.6640 - val_accuracy: 0.6300
# Epoch 25/30
# 50/50 [==============================] - 7s 135ms/step - loss: 0.6389 - accuracy: 0.6275 - val_loss: 0.6736 - val_accuracy: 0.6300
# Epoch 26/30
# 50/50 [==============================] - 7s 136ms/step - loss: 0.6513 - accuracy: 0.6375 - val_loss: 0.6629 - val_accuracy: 0.6200
# Epoch 27/30
# 50/50 [==============================] - 8s 165ms/step - loss: 0.6462 - accuracy: 0.6175 - val_loss: 0.6562 - val_accuracy: 0.6050
# Epoch 28/30
# 50/50 [==============================] - 8s 160ms/step - loss: 0.6385 - accuracy: 0.6350 - val_loss: 0.6612 - val_accuracy: 0.6800
# Epoch 29/30
# 50/50 [==============================] - 8s 152ms/step - loss: 0.6313 - accuracy: 0.6550 - val_loss: 0.6619 - val_accuracy: 0.6550
# Epoch 30/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.6269 - accuracy: 0.6225 - val_loss: 0.6419 - val_accuracy: 0.6400
# dog
