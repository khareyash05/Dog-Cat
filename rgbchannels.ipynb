# %%
import numpy as np
from keras.preprocessing.image import ImageDataGenerator,img_to_array,array_to_img,load_img
import cv2
import matplotlib.pyplot as plt

# %%
img1 = cv2.imread('dataset/oic.jpg')
plt.imshow(img1)
plt.show()

# %%
a = img1
a[:,:,0]=0
a = array_to_img(a)
a
# Out:
# <PIL.Image.Image image mode=RGB size=800x533 at 0x2B643496970>

# %%
c = img1
c[:,:,1]=0
c = array_to_img(c)
c
# Out:
# <PIL.Image.Image image mode=RGB size=800x533 at 0x2B6434A2DC0>

# %%
# cropping an image
img_crop = img1[100:300,200:500] # top left is origin
img_crop1 = array_to_img(img_crop)
img_crop1
# Out:
# <PIL.Image.Image image mode=RGB size=300x200 at 0x2B637CEDCA0>
