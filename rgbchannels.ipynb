# %%
import numpy as np
from keras.preprocessing.image import ImageDataGenerator,img_to_array,array_to_img,load_img
from skimage.io import imread, imshow
import cv2

# %%
img1 = imread('dataset/oic.jpg')
img = array_to_img(img1)
img
# Out:
# <PIL.Image.Image image mode=RGB size=800x533 at 0x27757089AF0>

# %%
a = img1
a[:,:,0]=0
a = array_to_img(a)
a
# Out:
# <PIL.Image.Image image mode=RGB size=800x533 at 0x2774C2D1490>

# %%
c = img1
c[:,:,1]=0
c = array_to_img(c)
c
# Out:
# <PIL.Image.Image image mode=RGB size=800x533 at 0x27755E98850>

# %%
img_crop = img1[100:300,200:500] # top left is origin
img_crop1 = array_to_img(img_crop)
img_crop1
# Out:
# <PIL.Image.Image image mode=RGB size=300x200 at 0x2774C2D1460>
